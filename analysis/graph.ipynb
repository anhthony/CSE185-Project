# %%
import matplotlib.pyplot as plt 

sizes = []
for i in range(1,21):
    sizes.append(i*100000)

#Runtime from runtimeBySizeVarDetect.txt
runtimes_vard = [50.851+12.532, 53.593+12.564, 57.252+12.925, 56.568+13.530,
            59.138 + 13.167, 64.439 + 14.182, 69.417 + 15.217, 72.376 + 15.032,
            76.961 + 16.507, 75.523+19.289, 78.740+13.612, 81.712 + 18.134, 
            81.275 + 15.833, 83.047 + 15.286, 90.551 + 16.235, 93.238 + 15.123,
            95.780 + 16.830, 96.900 + 14.366, 97.461 + 15.274, 101.256 + 17.899]
#Runtimes from runtimeBySizeVarScan.txt
runtimes_vars = [6.833+0.239, 30.224 + 0.710 , 37.815 + 0.836, 35.839 + 0.634,
                 41.296 + 0.672, 46.380 + 0.767, 47.714 + 0.824, 75.801 + 0.928,
                 51.103 + 0.741, 54.081 + 0.992, 53.070+0.667, 55.726 + 0.791,
                 55.938 + 1.053, 64.661 + 1.055, 72.050 + 1.558, 72.692 + 1.455,
                 92.160 + 1.499, 73.747 + 1.383, 89.534 + 1.605, 75.618 + 1.321]
plt.title("Runtime vs. Input File Size For VarDetect and VarScan (NA18555)")
plt.xlabel("Input Size (million bases)")
plt.ylabel("Runtime (in seconds)")
plt.plot(sizes, runtimes_vard, linestyle='--', marker='o', color='b', label='VarDetect')
plt.plot(sizes, runtimes_vars, linestyle='--', marker='o', color='g', label='VarScan')
plt.legend()
plt.savefig('runtimeByInputSize.jpg')
plt.show()
